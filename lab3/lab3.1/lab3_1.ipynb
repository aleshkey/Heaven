# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv('car_data.csv')

# Отображение первых нескольких записей
data.head(100)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# ..            ...   ...            ...            ...         ...       ...
# 95  corolla altis  2012           5.85          18.61       72000    Petrol
# 96         innova  2016          20.75          25.39       29000    Diesel
# 97  corolla altis  2017          17.00          18.64        8700    Petrol
# 98  corolla altis  2013           7.05          18.61       45000    Petrol
# 99       fortuner  2010           9.65          20.45       50024    Diesel
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0
# ..         ...          ...    ...
# 95      Dealer       Manual      0
# 96      Dealer    Automatic      0
# 97      Dealer       Manual      0
# 98      Dealer       Manual      0
# 99      Dealer       Manual      0
#
# [100 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# Группировка данных по марке автомобиля и суммирование количества продаж
brand_sales = data.head(100).groupby('Car_Name')['Selling_Price'].count().sort_values(ascending=False)

# Создание столбчатой диаграммы
plt.figure(figsize=(10, 6))
plt.bar(brand_sales.index, brand_sales.values)
plt.xlabel('Название автомобиля')
plt.ylabel('Количество продаж')
plt.title('Продажи автомобилей по назвнию')
plt.xticks(rotation=90)
plt.show()

# %%
# Создание гистограммы распределения цен продажи
plt.figure(figsize=(10, 6))
plt.hist(data['Selling_Price'], bins=20, edgecolor='black')
plt.xlabel('Цена продажи')
plt.ylabel('Частота')
plt.title('Распределение цен продажи автомобилей')
plt.show()

# %%
# Группировка данных по году производства и вычисление средней цены продажи
yearly_avg_price = data.groupby('Year')['Selling_Price'].mean()

# Создание линейного графика
plt.figure(figsize=(10, 6))
plt.plot(yearly_avg_price.index, yearly_avg_price.values, marker='o')
plt.xlabel('Год производства')
plt.ylabel('Средняя цена продажи')
plt.title('Динамика средней цены продажи автомобилей по годам')
plt.show()

# %%
# Создание диаграммы размаха для цен продажи по типу топлива
plt.figure(figsize=(10, 6))
plt.boxplot([data[data['Fuel_Type'] == 'Petrol']['Selling_Price'],
             data[data['Fuel_Type'] == 'Diesel']['Selling_Price'],
            ],
            labels=['Petrol', 'Diesel'])
plt.xlabel('Тип топлива')
plt.ylabel('Цена продажи')
plt.title('Диаграмма размаха цен продажи по типу топлива')
plt.show()

# %%
# Группировка данных по типу топлива и подсчет количества автомобилей
fuel_counts = data['Fuel_Type'].value_counts()

# Создание радиальной диаграммы
plt.figure(figsize=(8, 8))
plt.pie(fuel_counts.values, labels=fuel_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Распределение типов топлива')
plt.axis('equal')
plt.show()

# %%
# Создание диаграммы рассеяния для цены продажи и пробега автомобилей
plt.figure(figsize=(10, 6))
plt.scatter(data['Selling_Price'], data['Kms_Driven'], alpha=0.5)
plt.xlabel('Цена продажи')
plt.ylabel('Пробег (в км)')
plt.title('Диаграмма рассеяния цены продажи и пробега')
plt.show()
